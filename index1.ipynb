# %% [markdown]
# ## Introduction to Sqlite

# %%
import sqlite3
import pandas as pd
conn =  sqlite3.connect("data.sqlite")

# %% [markdown]
# ## Viewing the Tables

# %%
df = df.read_sql("""SELECT name from sqlite_master WHERE type = "table";""" , conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = df.read_sql("""SELECT name from sqlite_master WHERE type = "table";""" , conn)
#
# NameError: name 'df' is not defined
